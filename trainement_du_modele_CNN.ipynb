# %%
import numpy as np
import cv2
import tensorflow
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils
import dlib
import shutil, sys, os, dlib, glob, cv2

# %%
from scipy.spatial import distance as dist
from imutils import face_utils
from threading import Thread
from IPython.display import display, Javascript, Image
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time
import os
import dlib
from skimage import io

# %%
data = np.load(r'C:\Users\User\Memoire\Somnolence-Detection-Project--main\datasetNPZ\dataset_compressed.npz', allow_pickle=True)
X = data['arr_0']
Y = data['arr_1']
X = list(X)
Y = list(Y)
print(len(X))
print(len(Y))
# Out:
# 1452
# 1452

# %%
print(data.files)
# Out:
# ['arr_0', 'arr_1']

# %%
for i in range(len(X)):
    img = X[i]
    img = cv2.resize(img, (32, 32))
    X[i] = img
    
print(len(X))
print(X[0].shape)
# Out:
# 1452
# (32, 32, 3)

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print(Y.shape)
print(Y[0])
print(set(Y))
# Out:
# (1452,)
# 0
# {np.int64(0), np.int64(1)}

# %%
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)
# Out:
# (1452, 32, 32, 3)
# (1452,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1161, 32, 32, 3)
# (1161,)
# (291, 32, 32, 3)
# (291,)
# (1161, 32, 32, 3)
# (1161, 2)
# (291, 32, 32, 3)
# (291, 2)

# %%
def somnolance_detection_model(input_shape=(32, 32, 3)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv5', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv6', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv7', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    
    optimizer = Adam(0.0001)
    #model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
model= somnolance_detection_model(input_shape=(32, 32, 3))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                  │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4 (Conv2D)                  │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv6 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv7 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc3 (Dense)                     │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 227,554 (888.88 KB)
#  Trainable params: 226,786 (885.88 KB)
#  Non-trainable params: 768 (3.00 KB)

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=100, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# c:\Users\User\anaconda3\envs\PRO_IA\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.5435 - loss: 1.2077 - val_accuracy: 0.5326 - val_loss: 1.3819
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.6489 - loss: 0.7254 - val_accuracy: 0.5361 - val_loss: 0.9155
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.7427 - loss: 0.5924 - val_accuracy: 0.6014 - val_loss: 0.6566
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.8136 - loss: 0.4403 - val_accuracy: 0.6495 - val_loss: 0.5393
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.8260 - loss: 0.4156 - val_accuracy: 0.8282 - val_loss: 0.4593
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.8711 - loss: 0.3729 - val_accuracy: 0.8625 - val_loss: 0.4063
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.8951 - loss: 0.3476 - val_accuracy: 0.9003 - val_loss: 0.3426
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.8987 - loss: 0.2284 - val_accuracy: 0.9003 - val_loss: 0.2921
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9283 - loss: 0.1950 - val_accuracy: 0.9141 - val_loss: 0.2488
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9397 - loss: 0.1915 - val_accuracy: 0.9244 - val_loss: 0.2312
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9218 - loss: 0.1745 - val_accuracy: 0.9450 - val_loss: 0.1824
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.9486 - loss: 0.1426 - val_accuracy: 0.9450 - val_loss: 0.1553
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.9646 - loss: 0.1125 - val_accuracy: 0.9588 - val_loss: 0.1178
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9672 - loss: 0.1074 - val_accuracy: 0.9691 - val_loss: 0.1000
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9663 - loss: 0.0955 - val_accuracy: 0.9656 - val_loss: 0.0861
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.9765 - loss: 0.0796 - val_accuracy: 0.9759 - val_loss: 0.0754
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9745 - loss: 0.0766 - val_accuracy: 0.9759 - val_loss: 0.0666
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.9774 - loss: 0.0633 - val_accuracy: 0.9828 - val_loss: 0.0535
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.9656 - loss: 0.0937 - val_accuracy: 0.9897 - val_loss: 0.0488
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.9849 - loss: 0.0427 - val_accuracy: 0.9897 - val_loss: 0.0380
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.9882 - loss: 0.0325 - val_accuracy: 0.9794 - val_loss: 0.0508
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.9762 - loss: 0.0547 - val_accuracy: 0.9794 - val_loss: 0.0392
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9860 - loss: 0.0418 - val_accuracy: 0.9897 - val_loss: 0.0339
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9911 - loss: 0.0308 - val_accuracy: 0.9485 - val_loss: 0.1393
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.9623 - loss: 0.1029 - val_accuracy: 0.9450 - val_loss: 0.1179
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9814 - loss: 0.0525 - val_accuracy: 0.9897 - val_loss: 0.0199
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.9812 - loss: 0.0512 - val_accuracy: 0.9828 - val_loss: 0.0414
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9830 - loss: 0.0348 - val_accuracy: 0.9863 - val_loss: 0.0396
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9899 - loss: 0.0368 - val_accuracy: 0.9828 - val_loss: 0.0386
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9873 - loss: 0.0390 - val_accuracy: 0.9794 - val_loss: 0.0371
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9921 - loss: 0.0228 - val_accuracy: 0.9725 - val_loss: 0.0390
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9909 - loss: 0.0253 - val_accuracy: 0.9656 - val_loss: 0.1268
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9914 - loss: 0.0298 - val_accuracy: 0.9725 - val_loss: 0.0795
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9877 - loss: 0.0250 - val_accuracy: 0.9416 - val_loss: 0.1536
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9755 - loss: 0.0763 - val_accuracy: 0.9244 - val_loss: 0.1904
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9767 - loss: 0.0623 - val_accuracy: 0.9107 - val_loss: 0.2441
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9778 - loss: 0.0657 - val_accuracy: 0.9347 - val_loss: 0.1738
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9799 - loss: 0.0514 - val_accuracy: 0.9588 - val_loss: 0.1278
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.9802 - loss: 0.0578 - val_accuracy: 0.9725 - val_loss: 0.1018
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9940 - loss: 0.0254 - val_accuracy: 0.9828 - val_loss: 0.0711
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9905 - loss: 0.0355 - val_accuracy: 0.9828 - val_loss: 0.0426
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9951 - loss: 0.0254 - val_accuracy: 0.9897 - val_loss: 0.0199
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9888 - loss: 0.0267 - val_accuracy: 0.9966 - val_loss: 0.0135
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.9901 - loss: 0.0285 - val_accuracy: 0.9966 - val_loss: 0.0134
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9911 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.9933 - loss: 0.0242 - val_accuracy: 0.9966 - val_loss: 0.0154
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.9910 - loss: 0.0283 - val_accuracy: 0.9931 - val_loss: 0.0179
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9973 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9915 - loss: 0.0457 - val_accuracy: 0.9038 - val_loss: 0.3959
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.9592 - loss: 0.1249 - val_accuracy: 0.8832 - val_loss: 0.4066
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9627 - loss: 0.1102 - val_accuracy: 0.9519 - val_loss: 0.1151
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9433 - loss: 0.1301 - val_accuracy: 0.8591 - val_loss: 0.4983
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.9552 - loss: 0.1005 - val_accuracy: 0.9553 - val_loss: 0.1125
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9768 - loss: 0.0687 - val_accuracy: 0.9450 - val_loss: 0.1773
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9759 - loss: 0.0675 - val_accuracy: 0.9691 - val_loss: 0.1358
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9703 - loss: 0.0561 - val_accuracy: 0.9794 - val_loss: 0.0909
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9899 - loss: 0.0291 - val_accuracy: 0.9691 - val_loss: 0.0835
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9831 - loss: 0.0414 - val_accuracy: 0.9656 - val_loss: 0.1092
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9609 - loss: 0.1113 - val_accuracy: 0.9485 - val_loss: 0.1638
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9608 - loss: 0.1032 - val_accuracy: 0.9863 - val_loss: 0.0511
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.9814 - loss: 0.0535 - val_accuracy: 0.9347 - val_loss: 0.1531
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9710 - loss: 0.0651 - val_accuracy: 0.9794 - val_loss: 0.0651
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9813 - loss: 0.0734 - val_accuracy: 0.9897 - val_loss: 0.0280
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9863 - loss: 0.0440 - val_accuracy: 0.9966 - val_loss: 0.0188
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9883 - loss: 0.0260 - val_accuracy: 0.9966 - val_loss: 0.0202
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9954 - loss: 0.0169 - val_accuracy: 0.9966 - val_loss: 0.0209
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9883 - loss: 0.0323 - val_accuracy: 0.9759 - val_loss: 0.0443
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.9913 - loss: 0.0282 - val_accuracy: 0.9691 - val_loss: 0.1249
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9839 - loss: 0.0411 - val_accuracy: 0.9897 - val_loss: 0.0199
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9909 - loss: 0.0256 - val_accuracy: 0.9931 - val_loss: 0.0151
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.9901 - loss: 0.0201 - val_accuracy: 0.9931 - val_loss: 0.0069
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9979 - loss: 0.0141 - val_accuracy: 0.9966 - val_loss: 0.0064
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9982 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.9956 - loss: 0.0154 - val_accuracy: 0.9966 - val_loss: 0.0043
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9992 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9975 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9951 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9966 - val_loss: 0.0036
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9928 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.9965 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 7.9081e-04
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.9970 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 5.3190e-04
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9986 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 6.2739e-04
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 7.5566e-04
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.9980 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 9.3743e-04
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9979 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 8.7250e-04
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9965 - loss: 0.0111 - val_accuracy: 0.9966 - val_loss: 0.0123
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9988 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9997 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9962 - loss: 0.0105 - val_accuracy: 0.9966 - val_loss: 0.0067
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9966 - val_loss: 0.0098
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9978 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9988 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9980 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9998 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9986 - loss: 0.0019 - val_accuracy: 0.9931 - val_loss: 0.0159
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9992 - loss: 0.0024 - val_accuracy: 0.9897 - val_loss: 0.0247
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9979 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 5.5110e-04
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9985 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 3.9743e-04
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9984 - loss: 0.0036 - val_accuracy: 0.9966 - val_loss: 0.0052

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
pred = model.evaluate(X_test, Y_test)
print(f'Test Set Accuracy: {pred[1]}')
print(f'Test Set Loss: {pred[0]}')
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9987 - loss: 0.0026
# Test Set Accuracy: 0.9965635538101196
# Test Set Loss: 0.005182459484785795

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_pred = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_pred, ypred))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       136
#            1       1.00      0.99      1.00       155
#
#     accuracy                           1.00       291
#    macro avg       1.00      1.00      1.00       291
# weighted avg       1.00      1.00      1.00       291

# %%
model.save(r'C:\Users\User\Memoire\Somnolence-Detection-Project--main\model\Somnolance_Detection_new.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
